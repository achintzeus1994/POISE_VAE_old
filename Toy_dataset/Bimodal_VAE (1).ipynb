# %%
import torch
import numpy as np
from torch.utils.data import DataLoader
import matplotlib
import matplotlib.pyplot as plt
import import_ipynb
import gibbs_sampler
import torch.nn as nn
import torch.optim as optim
from torch.nn import functional as F  #for the activation function

# %%
"""
I will create two datasets of one dimensional gaussian. Pass it through separate VAE. Do Gibbs sampling and see 
if I can learn true latent space
""" 

def sample(mu, var, nb_samples):
    """
    :param mu: torch.Tensor (features)
    :param var: torch.Tensor (features) (note: zero covariance)
    :return: torch.Tensor (nb_samples, features)
    """
    out = []
    for i in range(nb_samples):
        out += [torch.normal(mu, var.sqrt())]
    return torch.stack(out, dim=0)

# %%
## Creating synthetic datasets
nb_samples=5000
mu1  =torch.tensor(1.)   # . converts long to float
var1 =torch.tensor(2.1)
mu2  =torch.tensor(2.)   # . converts long to float
var2 =torch.tensor(3.1)

inp_data1=sample(mu1,var1,nb_samples)
inp_data1=inp_data1.unsqueeze(0)
inp_data1=torch.transpose(inp_data1,0,1)

inp_data2=sample(mu2,var2,nb_samples)
inp_data2=inp_data2.unsqueeze(0)
inp_data2=torch.transpose(inp_data2,0,1)

# %%
## for data visualization
data_vis1=inp_data1.numpy()
data_vis2=inp_data2.numpy()

fig, ax = plt.subplots(2,1)

#flg,(ax1,ax2)=plt.subplots(1,2,figsize=(6, 2))
#Panel a
n1,bins1,patches1=ax[0].hist(data_vis1,'auto',density=1)
y1=1/(np.sqrt(2*np.pi*var1))*np.exp(-0.5*(bins1-mu1.numpy())**2/var1)
ax[0].plot(bins1,y1,'--')
ax[0].set(xlabel='x',ylabel='p(x)')
#Panel b
n2,bins2,patches2=ax[1].hist(data_vis2,'auto',density=1)
y2=1/(np.sqrt(2*np.pi*var2))*np.exp(-0.5*(bins2-mu2.numpy())**2/var2)
ax[1].plot(bins2,y2,'--')
ax[1].set(xlabel='x',ylabel='p(x)')

plt.show()
print("mu1",mu1)
print("var1",var1)
print("mu2",mu2)
print("var2",var2)
# Out:
# mu1 tensor(1.)
# var1 tensor(2.1000)
# mu2 tensor(2.)
# var2 tensor(3.1000)

# %%
## Transforming data to a higher dimension
"""
inp_data= samplesx1
fun_A   = 1xdim_exp
data    = samplesxdim_exp   (data = inp_dataxfun_A)
"""
dim_exp = 2 
fun_A1   = torch.normal(0, 1, size=(1, dim_exp))  ## random tensor of size dim_expxdata_samples mean=0, var=1, s
fun_A2   = torch.normal(0, 1, size=(1, dim_exp))  ## random tensor of size dim_expxdata_samples mean=0, var=1, s
data1    = inp_data1*fun_A1
data2    = inp_data2*fun_A2
x1_cord = data1[:,0]
y1_cord = data1[:,1]
x2_cord = data2[:,0]
y2_cord = data2[:,1]
plt.plot(x1_cord,y1_cord, 'o', color='black')
plt.plot(x2_cord,y2_cord, 'o', color='red')
plt.show()

# %%
## Hyperparameters
epochs     = 10
batch_size = 128
lr         = 1e-4
device     = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
## Creating synthetic dataloader

train_loader_set1 = DataLoader(
    data1[0:int(0.8*nb_samples),],
    batch_size=batch_size,
    shuffle=True,
    drop_last=True
)
test_loader_set1 = DataLoader(
    data1[int(0.8*nb_samples):,],
    batch_size=batch_size,
    shuffle=True,
    drop_last=True
)
train_loader_set2 = DataLoader(
    data2[0:int(0.8*nb_samples),],
    batch_size=batch_size,
    shuffle=True,
    drop_last=True
)
test_loader_set2 = DataLoader(
    data2[int(0.8*nb_samples):,],
    batch_size=batch_size,
    shuffle=True,
    drop_last=True
)

# %%
## Neural net is like: [mu,logvar]=(relu(xA))B,x=sig((relu(zC))D)

latent_dim1 = 1
latent_dim2 = 1

class VAE(nn.Module):
    def __init__(self):
        super(VAE,self).__init__()
        self.gibbs                   = gibbs_sampler.gibbs_sampler()        
        ## Encoder set1
        self.set1_enc1 = nn.Linear(in_features = dim_exp,out_features = 2*latent_dim1)
        self.set1_enc2 = nn.Linear(in_features = 2*latent_dim1,out_features = 2*latent_dim1)
        ## Encoder set2
        self.set2_enc1 = nn.Linear(in_features = dim_exp,out_features = 2*latent_dim2)
        self.set2_enc2 = nn.Linear(in_features = 2*latent_dim2,out_features = 2*latent_dim2)
        ## Decoder set1
        self.set1_dec1 = nn.Linear(in_features = latent_dim1,out_features = dim_exp,bias=False)
        ## Decoder set2
        self.set2_dec1 = nn.Linear(in_features = latent_dim2,out_features = dim_exp,bias=False)
    
    def forward(self,x1,x2):
        data1    = x1
        data2    = x2
        ## encoding
        x1       = F.relu(self.set1_enc1(x1))
        x1       = self.set1_enc2(x1)
        x2       = F.relu(self.set2_enc1(x2))
        x2       = self.set2_enc2(x2)
        mu1      = x1[:,0]
        mu1      = mu1.unsqueeze(0)
        mu1      = torch.transpose(mu1,0,1)    
        log_var1 = x1[:,1]
        var1     = torch.exp(log_var1)
        var1     = var1.unsqueeze(0)
        var1     = torch.transpose(var1,0,1)    
        mu2      = x2[:,0]
        mu2      = mu2.unsqueeze(0)
        mu2      = torch.transpose(mu2,0,1)    
        log_var2 = x2[:,1]
        var2     = torch.exp(log_var2)
        var2     = var2.unsqueeze(0)
        var2     = torch.transpose(var2,0,1) 
        G,z1,z2,z1_prior,z2_prior = self.gibbs.calc(mu1,var1,mu2,var2)

        ## Creating Sufficient statistics
        T1_prior = torch.cat((z1_prior,torch.square(z1_prior)),1)     #sufficient statistics for prior of set1
        T2_prior = torch.cat((z2_prior,torch.square(z2_prior)),1)     #sufficient statistics for prior of set2
        T1_post = torch.cat((z1,torch.square(z1)),1)                  #sufficient statistics for posterior of set1
        T2_post = torch.cat((z2,torch.square(z2)),1)                  #sufficient statistics for posterior of set2
        lambda1 = torch.cat((mu1,var1),1)                             #Output of encoder for set1
        lambda2 = torch.cat((mu2,var2),1)                             #Output of encoder for set2        
        T_prior_sqrd = torch.sum(torch.square(z1_prior),1) +torch.sum(torch.square(z2_prior),1) #stores z^2+z'^2
        T_post_sqrd  = torch.sum(torch.square(z1),1) +torch.sum(torch.square(z2),1)
        # Sampling from logp(z,z')
        log_p_prior = -T_prior_sqrd+torch.matmul(torch.matmul(T1_prior,G),torch.transpose(T2_prior,0,1))
        # Sampling from log_q(z,z'|x,x')
        log_q_post  = -T_post_sqrd+torch.matmul(torch.matmul(T1_post,G),torch.transpose(T2_post,0,1))
        
        #Calculating KL divergence terms
        part_fun0 = torch.sum(torch.diagonal(log_q_post-log_p_prior,0))
        part_fun1 = -torch.sum(torch.mul(lambda1,T1_post.detach()))-torch.sum(torch.mul(lambda2,T2_post.detach())) #-lambda*Tq-lambda'Tq'
        T1_prior  = T1_prior.unsqueeze(2)
        T2_prior  = T2_prior.unsqueeze(2)
        T1_post   = T1_post.unsqueeze(1)
        T2_post   = T2_post.unsqueeze(1)
        part_fun2 = torch.sum(torch.mul(T1_prior*T2_prior,G)-torch.mul(T1_post*T2_post,G))            
        ## decoding

        reconstruction1=self.set1_dec1(z1)
        reconstruction2=self.set2_dec1(z2)
        
        ## loss
        mse_loss = nn.MSELoss(reduction='sum')
        MSE1 = mse_loss(reconstruction1, data1)
        MSE2 = mse_loss(reconstruction2, data2)
        KLD = part_fun0+part_fun1+part_fun2
        loss= MSE1+MSE2+KLD
        #print("part_fun0",part_fun0)
        #print("part_fun1",part_fun1)
        #print("part_fun2",part_fun2)

        return mu1,log_var1,mu2,log_var2,loss

# %%
model = VAE().to(device)
optimizer = optim.Adam(model.parameters(),lr=lr)

# %%
def train(model,dataloader1,dataloader2):
    model.train()
    running_loss = 0
    for i,(data1,data2) in enumerate(zip(dataloader1,dataloader2)):
        data1                        = data1.to(device)
        data2                        = data2.to(device)        
        mu1,log_var1,mu2,log_var2,loss = model(data1,data2)     
        running_loss                += loss.item()
        loss.backward()                      
        optimizer.step()
    #print(len(dataloader1.dataset)+len(dataloader2.dataset))

    train_loss = running_loss/(len(dataloader1.dataset)+len(dataloader2.dataset))
    return train_loss
def test(model,dataloader1,dataloader2):
    mean1_pred = []
    var1_pred  = []
    mean2_pred = []
    var2_pred  = []
    model.eval()
    running_loss = 0.0
    with torch.no_grad():
        for i,(data1,data2) in enumerate(zip(dataloader1,dataloader2)):
            data1                        = data1.to(device)
            data2                        = data2.to(device)        
            mu1,log_var1,mu2,log_var2,loss = model(data1,data2)  
            running_loss              += loss.item()
            mean1_pred                += [torch.mean(mu1)]
            var1_pred                 += [torch.mean(torch.exp(log_var1))]
            mean2_pred                += [torch.mean(mu2)]
            var2_pred                 += [torch.mean(torch.exp(log_var2))]
    test_loss   = running_loss/(len(dataloader1.dataset)+len(dataloader2.dataset))
    mean1_pred  = torch.stack(mean1_pred,dim=0)
    var1_pred   = torch.stack(var1_pred,dim=0)
    mean1_pred  = torch.mean(mean1_pred)
    var1_pred   = torch.mean(var1_pred)
    
    mean2_pred  = torch.stack(mean2_pred,dim=0)
    var2_pred   = torch.stack(var2_pred,dim=0)
    mean2_pred  = torch.mean(mean2_pred)
    var2_pred   = torch.mean(var2_pred)
    return test_loss,mean1_pred,var1_pred,mean2_pred,var2_pred

# %%
train_loss = []
test_loss = []
for epoch in range(epochs):
    print(f"Epoch {epoch+1} of {epochs}")
    train_epoch_loss = train(model,train_loader_set1,train_loader_set2)
    test_epoch_loss,mean1_pred,var1_pred,mean2_pred,var2_pred = test(model,test_loader_set1,test_loader_set1)
    train_loss.append(train_epoch_loss)
    test_loss.append(test_epoch_loss)
print(f"Train Loss    : {train_epoch_loss:.4f}")
print(f"Test Loss     :  {test_epoch_loss:.4f}")
print(f"Mean Pred set1:  {mean1_pred:.4f}")
print(f"Var  Pred set1:  {var1_pred:.4f}")
print(f"Mean Pred set2:  {mean2_pred:.4f}")
print(f"Var  Pred set2:  {var2_pred:.4f}")
# Out:
# Epoch 1 of 10
# part_fun0 tensor(107.1919, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-72
device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-70.3520, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-72.1178, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(87.9750, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-81.6311, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-14.6979, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(79.7941, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-76.7326, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-13.1095, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(118.3931, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-78.3953, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-38.7698, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(74.7074, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-94.1230, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-28.1432, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(144.1336, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-66.4792, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-48.2820, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(96.5221, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-77.4221, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-13.8915, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(150.9793, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-84.1960, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-63.1749, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(87.8346, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-94.9966, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-32.9139, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(127.6749, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-74.2272, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-47.4704, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(99.8841, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-70.5051, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-26.4586, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(89.8550, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-89.5166, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-29.3769, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(159.0086, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-76.3001, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-48.3563, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(110.9456, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-86.5892, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-35.7573, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(134.5588, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-60.4158, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-33.0079, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(68.4159, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-78.8077, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-1.8867, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(76.8482, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-91.5639, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-11.3960, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(121.2361, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-86.7001, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-46.7421, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(100.7781, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-72.8441, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-27.3208, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(74.7378, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-90.0732, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-19.4976, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(65.5634, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-81.2576, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-25.9648, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(139.0759, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-81.4386, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-48.5573, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(101.0355, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-68.0951, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-24.2175, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(134.8626, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-67.9353, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-47.5607, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(83.9864, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-79.9446, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-21.2807, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(94.8732, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-63.0864, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-15.9349, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(141.0336, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-81.8191, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-50.6903, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(102.9057, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-73.6179, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-34.9623, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(81.9024, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-74.8429, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-21.2156, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(122.0997, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-82.8816, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-48.9614, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(90.7955, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun1 tensor(-77.0071, device='cuda:0', grad_fn=<SubBackward0>)
# part_fun2 tensor(-29.0960, device='cuda:0', grad_fn=<SumBackward0>)
# part_fun0 tensor(121.6344, device='cuda:0')
# part_fun1 tensor(-80.5052, device='cuda:0')
# part_fun2 tensor(-29.7775, device='cuda:0')
# part_fun0 tensor(120.9551, device='cuda:0')
# part_fun1 tensor(-76.6173, device='cuda:0')
# part_fun2 tensor(-42.7063, device='cuda:0')
# part_fun0 tensor(79.0701, device='cuda:0')
# part_fun1 tensor(-82.9255, device='cuda:0')
# part_fun2 tensor(-12.2581, device='cuda:0')
# part_fun0 tensor(86.6892, device='cuda:0')
# part_fun1 tensor(-93.3128, device='cuda:0')
# part_fun2 tensor(-34.0637, device='cuda:0')
# part_fun0 tensor(122.5098, device='cuda:0')
# part_fun1 tensor(-64.6960, device='cuda:0')
# part_fun2 tensor(-29.6826, device='cuda:0')
# part_fun0 tensor(119.4555, device='cuda:0')
# part_fun1 tensor(-70.2224, device='cuda:0')
# part_fun2 tensor(-28.1407, device='cuda:0')
# part_fun0 tensor(93.6819, device='cuda:0')
# part_fun1 tensor(-81.3865, device='cuda:0')
# part_fun2 tensor(-34.0101, device='cuda:0')
# Train Loss    : 8.1417
# Test Loss     :  14.1125
# Mean Pred set1:  0.0340
# Var  Pred set1:  0.5622
# Mean Pred set2:  0.0792
# Var  Pred set2:  1.4630

# %%
flg,(ax1,ax2)=plt.subplots(1,2,figsize=(6, 2))
ax1.plot(train_loss)
ax1.set(xlabel='x',ylabel='loss',title='training loss')
ax2.plot(test_loss)
ax2.set(xlabel='x',ylabel='loss',title='test loss')
flg.tight_layout()
plt.show()

# %%
## Transforming data to a higher dimension
mean_pred  =torch.tensor(0.).cpu()   # . converts long to float
var_pred =torch.tensor(1.0).cpu()
gen_data  = sample(mean_pred,var_pred,nb_samples)
gen_data  = gen_data.unsqueeze(1)

"""
inp_data= samplesx1
fun_A   = 1xdim_exp
data    = samplesxdim_exp   (data = inp_dataxfun_A)
"""
#fun_A   = torch.normal(0, 1, size=(1, dim_exp))  ## random tensor of size dim_expxdata_samples mean=0, var=1, s
param_dict={}
for name, para in model.named_parameters():
    param_dict[name]=para

A1=param_dict["set1_dec1.weight"]
A2=param_dict["set2_dec1.weight"]
set1_dec1_wgt=A1
set2_dec1_wgt=A2
set1_dec1_wgt  = (torch.transpose(set1_dec1_wgt,0,1)).cpu()
set2_dec1_wgt  = (torch.transpose(set2_dec1_wgt,0,1)).cpu()

data1_sim= gen_data*set1_dec1_wgt
data2_sim= gen_data*set2_dec1_wgt

dat1_x_cord = data1_sim[:,0].cpu().detach().numpy()
dat1_y_cord = data1_sim[:,1].cpu().detach().numpy()
dat2_x_cord = data2_sim[:,0].cpu().detach().numpy()
dat2_y_cord = data2_sim[:,1].cpu().detach().numpy()

fig, ax = plt.subplots(2)

ax[0].plot(x1_cord,y1_cord, 'o', color='black',label='true set1')
ax[0].plot(x2_cord,y2_cord, 'o', color='red',label='true set2')
ax[0].legend()
ax[1].plot(dat1_x_cord,dat1_y_cord, 'o', color='black',label='gen set1')
ax[1].plot(dat2_x_cord,dat2_y_cord, 'o', color='red',label='gen set2')
ax[1].legend()
plt.show()

# %%
A= list(model.named_parameters())
A
# Out:
# [('set1_enc1.weight',
#   Parameter containing:
#   tensor([[ 0.2454,  0.5722],
#           [ 0.3943, -0.1476]], device='cuda:0', requires_grad=True)),
#  ('set1_enc1.bias',
#   Parameter containing:
#   tensor([ 0.7236, -0.0995], device='cuda:0', requires_grad=True)),
#  ('set1_enc2.weight',
#   Parameter containing:
#   tensor([[ 0.4390, -0.0900],
#           [ 0.4182,  0.4532]], device='cuda:0', requires_grad=True)),
#  ('set1_enc2.bias',
#   Parameter containing:
#   tensor([0.3881, 0.2806], device='cuda:0', requires_grad=True)),
#  ('set2_enc1.weight',
#   Parameter containing:
#   tensor([[ 0.1272, -0.6082],
#           [-0.3440,  0.4301]], device='cuda:0', requires_grad=True)),
#  ('set2_enc1.bias',
#   Parameter containing:
#   tensor([0.6419, 0.4150], device='cuda:0', requires_grad=True)),
#  ('set2_enc2.weight',
#   Parameter containing:
#   tensor([[ 0.6590, -0.4633],
#           [ 0.4109, -0.5425]], device='cuda:0', requires_grad=True)),
#  ('set2_enc2.bias',
#   Parameter containing:
#   tensor([-0.0008, -0.4217], device='cuda:0', requires_grad=True)),
#  ('set1_dec1.weight',
#   Parameter containing:
#   tensor([[ 0.2214],
#           [-0.7266]], device='cuda:0', requires_grad=True)),
#  ('set2_dec1.weight',
#   Parameter containing:
#   tensor([[0.7741],
#           [0.6413]], device='cuda:0', requires_grad=True))]

# %%
sample_dict={}
for name, para in model.named_parameters():
    sample_dict[name]=para

# %%
sample_dict["set1_enc1.weight"]
# Out:
# Parameter containing:
# tensor([[ 0.2454,  0.5722],
#         [ 0.3943, -0.1476]], device='cuda:0', requires_grad=True)

# %%
model.named_parameters()
# Out:
# <generator object Module.named_parameters at 0x7f93e4295580>
